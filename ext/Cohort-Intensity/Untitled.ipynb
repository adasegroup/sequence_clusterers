# %%
import os
path_to_files = 'data/simulated_Hawkes/simulated_Hawkes/tmp_trunc_K4_C5'

files = os.listdir(path_to_files)

# %%
import pandas as pd

# %%
import torch
def cmp_to_key(mycmp):
    'Convert a cmp= function into a key= function'
    class K(object):
        def __init__(self, obj, *args):
            self.obj = obj
        def __lt__(self, other):
            return mycmp(self.obj, other.obj) < 0
        def __gt__(self, other):
            return mycmp(self.obj, other.obj) > 0
        def __eq__(self, other):
            return mycmp(self.obj, other.obj) == 0
        def __le__(self, other):
            return mycmp(self.obj, other.obj) <= 0
        def __ge__(self, other):
            return mycmp(self.obj, other.obj) >= 0
        def __ne__(self, other):
            return mycmp(self.obj, other.obj) != 0
    return K

def compare(a,b):
    tmp1 = int(a[:-4])
    tmp2 = int(b[:-4])
    return tmp1 - tmp2

def get_partition(df, num_of_steps, num_of_classes, end_time = None):
    if end_time == None:
        end_time = df['time'][len(df['time'])-1]
    res = torch.zeros(num_of_steps, num_of_classes + 1)
    dt = end_time/num_of_steps
    res[:,0] = end_time/num_of_steps
    for i in range(len(df['time'])):
        k = int(df['time'][i]/dt)
        if k == num_of_steps:
            k-=1
        res[k,int(df['event'][i])+1] += 1
    return res
def get_dataset(path_to_files, n_classes, n_steps):
    files = os.listdir(path_to_files)
    target = None
    if 'clusters.csv' in files:
        files.remove('clusters.csv')
        target = torch.Tensor(pd.read_csv(path_to_files+'/clusters.csv')['cluster_id'])
    #print(target)
    files = sorted(files, key = cmp_to_key(compare))
    data = torch.zeros(len(files), n_steps, n_classes + 1)
    for i, f in enumerate(files):
        df = pd.read_csv(path_to_files+'/'+f)
        data[i,:,:] = get_partition(df, n_steps, n_classes)
    return data, target

# %%
data, target = get_dataset(path_to_files, 5, 1024)

# %%
import torch
from models.models import LSTM_cluster_point_processes
from utils.trainers import Trainer_clusterwise

device = 'cuda:1'

model = LSTM_cluster_point_processes(6,128, 3, 5, 4, 1024, dropout = 0.3).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.01, weight_decay = 1e-4)
trainer = Trainer_clusterwise(model, optimizer, device, data, data, target, target, 4,\
                             l = 1, max_epochs = 100, max_m_step_epochs = 30,\
                              lr_update_tol = 15, lr_update_param = 0.9,\
                              batch_size = 150)

# %%
losses, purs, purs_val = trainer.train()
# Out:
# Beginning e-step
# tensor(1600., device='cuda:1')
# Cluster partition
# Cluster 0 :  0.0475  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.085  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.848125  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.019375  with pi =  tensor(0.2500, device='cuda:1')
# Purity for random model: 0.28625
# Beginning m-step
# Loss on sub_epoch 1/30: 66162.021875
# Loss on sub_epoch 11/30: 63070.371875
# Loss on sub_epoch 21/30: 63023.815625
# Cluster partition
# Cluster 0 :  0.0225  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.548125  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.08875  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.340625  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 1/100 average loss = 63224.22875, purity = 0.42875
# Validation loss = 671797.125, purity = 0.42875
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Updating lr
# Loss on sub_epoch 1/30: 63091.260546875
# Loss on sub_epoch 11/30: 62959.733984375
# Loss on sub_epoch 21/30: 63173.024609375
# Cluster partition
# Cluster 0 :  0.4275  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.3275  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.08625  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.15875  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 2/100 average loss = 62877.2691015625, purity = 0.41812499999999997
# Validation loss = 658097.6875, purity = 0.41812499999999997
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Loss on sub_epoch 1/30: 61025.32421875
# Loss on sub_epoch 11/30: 60626.221484375
# Updating lr
# Loss on sub_epoch 21/30: 60586.518359375
# Cluster partition
# Cluster 0 :  0.064375  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.09125  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.761875  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.0825  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 3/100 average loss = 60746.11822916667, purity = 0.39187500000000003
# Validation loss = 652229.125, purity = 0.39187500000000003
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Loss on sub_epoch 1/30: 60567.891015625
# Updating lr
# Loss on sub_epoch 11/30: 60657.984375
# Loss on sub_epoch 21/30: 60694.75546875
# Cluster partition
# Cluster 0 :  0.154375  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.436875  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.220625  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.188125  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 4/100 average loss = 60636.23192708333, purity = 0.36375
# Validation loss = 646751.5, purity = 0.36375
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Loss on sub_epoch 1/30: 60506.2828125
# Updating lr
# Loss on sub_epoch 11/30: 60769.03125
# Loss on sub_epoch 21/30: 60337.45703125
# Cluster partition
# Cluster 0 :  0.128125  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.078125  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.706875  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.086875  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 5/100 average loss = 60541.880520833336, purity = 0.4
# Validation loss = 644462.875, purity = 0.4
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Updating lr
# Loss on sub_epoch 1/30: 60452.279296875
# Loss on sub_epoch 11/30: 60566.827734375
# Loss on sub_epoch 21/30: 60547.058203125
# Updating lr
# Cluster partition
# Cluster 0 :  0.4725  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.260625  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.094375  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.1725  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 6/100 average loss = 60359.291692708335, purity = 0.419375
# Validation loss = 646293.75, purity = 0.419375
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Loss on sub_epoch 1/30: 60304.668359375
# Loss on sub_epoch 11/30: 60058.013671875
# Loss on sub_epoch 21/30: 60066.31796875
# Updating lr
# Cluster partition
# Cluster 0 :  0.228125  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.12625  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.4675  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.178125  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 7/100 average loss = 60306.0394921875, purity = 0.430625
# Validation loss = 642609.4375, purity = 0.430625
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Loss on sub_epoch 1/30: 59988.03828125
# Loss on sub_epoch 11/30: 60243.18828125
# Loss on sub_epoch 21/30: 60120.534375
# Updating lr
# Cluster partition
# Cluster 0 :  0.1425  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.123125  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.52375  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.210625  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 8/100 average loss = 60197.43015625, purity = 0.42000000000000004
# Validation loss = 642172.375, purity = 0.42000000000000004
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Loss on sub_epoch 1/30: 60423.701953125
# Loss on sub_epoch 11/30: 59999.64453125
# Loss on sub_epoch 21/30: 60112.13203125
# Updating lr
# Cluster partition
# Cluster 0 :  0.254375  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.1925  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.2725  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.280625  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 9/100 average loss = 60166.5662890625, purity = 0.449375
# Validation loss = 640527.3125, purity = 0.449375
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Loss on sub_epoch 1/30: 60147.558203125
# Loss on sub_epoch 11/30: 59778.697265625
# Loss on sub_epoch 21/30: 60138.1625
# Updating lr
# Cluster partition
# Cluster 0 :  0.2175  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 1 :  0.2775  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 2 :  0.243125  with pi =  tensor(0.2500, device='cuda:1')
# Cluster 3 :  0.261875  with pi =  tensor(0.2500, device='cuda:1')
# On epoch 10/100 average loss = 60036.88889322917, purity = 0.47124999999999995
# Validation loss = 640118.3125, purity = 0.47124999999999995
# Beginning e-step
# tensor(1600., device='cuda:1')
# Beginning m-step
# Loss on sub_epoch 1/30: 60105.13671875
# Everything failed!
# Everything failed!
# ValueErrorTraceback (most recent call last)
# <ipython-input-6-64226e875129> in <module>
# ----> 1 losses, purs, purs_val = trainer.train()
#
# ValueError: too many values to unpack (expected 3)

# %%
# losses, purs = trainer.train()

# %%
losses, purs = trainer.train()
# Out:
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.51375
# Beginning m-step
# Loss on sub_epoch 1/30: 15105.7927734375
# Loss on sub_epoch 11/30: 11890.847265625
# Loss on sub_epoch 21/30: 11710.6833984375
# On epoch 1/100 average loss = 12044.801451822917, purity = 0.68125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 11489.5048828125
# Loss on sub_epoch 11/30: 11243.4041015625
# Updating lr
# Loss on sub_epoch 21/30: 11540.073046875
# On epoch 2/100 average loss = 11344.5803125, purity = 0.7075
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 11333.2453125
# Loss on sub_epoch 11/30: 11256.861328125
# Updating lr
# Loss on sub_epoch 21/30: 11221.6671875
# On epoch 3/100 average loss = 11262.53220703125, purity = 0.76625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 11271.055859375
# Loss on sub_epoch 11/30: 11238.580078125
# Loss on sub_epoch 21/30: 11267.84296875
# Updating lr
# On epoch 4/100 average loss = 11185.32916015625, purity = 0.8262499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 11113.2259765625
# Loss on sub_epoch 11/30: 11073.2115234375
# Loss on sub_epoch 21/30: 11062.8236328125
# Updating lr
# On epoch 5/100 average loss = 11088.614837239584, purity = 0.8575
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 11079.4841796875
# Loss on sub_epoch 11/30: 11022.7267578125
# Loss on sub_epoch 21/30: 10936.626953125
# Updating lr
# On epoch 6/100 average loss = 10993.350279947917, purity = 0.9575
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 10775.6634765625
# Loss on sub_epoch 11/30: 10691.4802734375
# Loss on sub_epoch 21/30: 10635.4796875
# On epoch 7/100 average loss = 10670.929934895834, purity = 0.9862500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 10582.636328125
# Updating lr
# Loss on sub_epoch 11/30: 10535.3873046875
# Loss on sub_epoch 21/30: 10523.496484375
# On epoch 8/100 average loss = 10540.089108072916, purity = 0.99
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 10465.215234375
# Updating lr
# Loss on sub_epoch 11/30: 10544.4900390625
# Loss on sub_epoch 21/30: 10461.53515625
# On epoch 9/100 average loss = 10502.39380859375, purity = 0.99
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 10576.8619140625
# Updating lr
# Loss on sub_epoch 11/30: 10587.026953125
# Loss on sub_epoch 21/30: 10503.19453125
# On epoch 10/100 average loss = 10507.050455729166, purity = 0.99
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 10430.7337890625
# Updating lr
# Loss on sub_epoch 11/30: 10439.67421875
# Loss on sub_epoch 21/30: 10486.3501953125
# On epoch 11/100 average loss = 10466.021302083333, purity = 0.99
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-26-48fd12c44950> in <module>
# ----> 1 losses, purs = trainer.train()
#
# /mnt/Cohort-Intensity/utils/trainers.py in train(self)
#     179             pur = purity(clusters,self.target_train)
#     180         return log_likelihood_curve, [np.mean(ll), pur]
# --> 181     def train(self):
#     182         losses = []
#     183         purities = []
#
# /mnt/Cohort-Intensity/utils/trainers.py in m_step(self)
#     153         if np.mean(log_likelihood) > self.prev_loss:
#     154             self.update_checker += 1
# --> 155             if self.update_checker >= self.lr_update_tol:
#     156                 self.update_checker = 0
#     157                 print('Updating lr')
#
# /mnt/Cohort-Intensity/utils/trainers.py in train_epoch(self, epoch)
#     137             lambdas = self.model(self.X_train)
#     138             self.gamma = self.compute_gamma(lambdas)
# --> 139             print(torch.sum(self.gamma))
#     140     def train_epoch(self, epoch):
#     141         indices = np.random.permutation(self.N)
#
# /usr/local/lib/python3.7/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# KeyboardInterrupt:

# %%
import numpy as np
n_tries = 0
purs = []
stds = []
divs = [16,32,64,128,256,512,512+256,1024]
for div in divs:
    res = []
    while n_tries<5:
        data, target = get_dataset(path_to_files, 5, div)
        device = 'cuda:0'

        model = LSTM_cluster_point_processes(6, 128, 3, 5, 2, div, dropout = 0.3).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr = 0.001, weight_decay = 1e-4)
        trainer = Trainer_clusterwise(model, optimizer, device, data, target, 2,\
                                 max_epochs = 10, max_m_step_epochs = 30,\
                                  lr_update_tol = 15, lr_update_param = 0.1,\
                                  batch_size = 100)
        losses, purys = trainer.train()
        if purys:
            res.append(max(purys))
            n_tries += 1
    print('div:',div,np.mean(res),'+-', np.std(res))
    purs.append(np.mean(res))
    stds.append(np.std(res))
    n_tries = 0
# Out:
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.56125
# Beginning m-step
# Loss on sub_epoch 1/30: 8691.068150111607
# Loss on sub_epoch 11/30: 6911.942592075893
# Loss on sub_epoch 21/30: 6719.337193080357
# On epoch 1/10 average loss = 7009.695805431547, purity = 0.5925
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6609.807826450893
# Updating lr
# Loss on sub_epoch 11/30: 6519.581473214285
# Loss on sub_epoch 21/30: 6435.210518973215
# On epoch 2/10 average loss = 6488.663325427828, purity = 0.61375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6468.265276227678
# Loss on sub_epoch 11/30: 6451.822823660715
# Updating lr
# Loss on sub_epoch 21/30: 6448.0205078125
# On epoch 3/10 average loss = 6415.738337053572, purity = 0.5925
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6412.758021763393
# Updating lr
# Loss on sub_epoch 11/30: 6384.948102678572
# Loss on sub_epoch 21/30: 6423.340053013393
# On epoch 4/10 average loss = 6404.58562593006, purity = 0.59125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6392.676199776785
# Updating lr
# Loss on sub_epoch 11/30: 6394.196358816965
# Loss on sub_epoch 21/30: 6405.866489955357
# Updating lr
# On epoch 5/10 average loss = 6395.069617280506, purity = 0.58375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6462.29541015625
# Loss on sub_epoch 11/30: 6398.606863839285
# Loss on sub_epoch 21/30: 6348.499372209822
# On epoch 6/10 average loss = 6405.720545014881, purity = 0.5825
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6366.360630580357
# Updating lr
# Loss on sub_epoch 11/30: 6416.028599330357
# Loss on sub_epoch 21/30: 6352.503976004465
# On epoch 7/10 average loss = 6389.071205357143, purity = 0.585
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6347.992606026785
# Updating lr
# Loss on sub_epoch 11/30: 6435.116489955357
# Loss on sub_epoch 21/30: 6364.43212890625
# On epoch 8/10 average loss = 6404.126720610119, purity = 0.58625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6419.531319754465
# Updating lr
# Loss on sub_epoch 11/30: 6365.567522321428
# Loss on sub_epoch 21/30: 6409.202497209822
# On epoch 9/10 average loss = 6382.708628627232, purity = 0.58375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6436.454799107143
# Updating lr
# Loss on sub_epoch 11/30: 6363.132184709822
# Loss on sub_epoch 21/30: 6372.542898995535
# On epoch 10/10 average loss = 6390.171565755209, purity = 0.58125
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.6325000000000001
# Beginning m-step
# Loss on sub_epoch 1/30: 9465.353236607143
# Loss on sub_epoch 11/30: 7069.107700892857
# Loss on sub_epoch 21/30: 6752.691127232143
# On epoch 1/10 average loss = 7094.259937686012, purity = 0.6112500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6595.314871651785
# Loss on sub_epoch 11/30: 6517.409458705357
# Loss on sub_epoch 21/30: 6395.070103236607
# Updating lr
# On epoch 2/10 average loss = 6480.072279575893, purity = 0.6487499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6313.966099330357
# Loss on sub_epoch 11/30: 6240.853515625
# Loss on sub_epoch 21/30: 6351.089913504465
# Updating lr
# On epoch 3/10 average loss = 6347.053880673363, purity = 0.6875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6362.625348772322
# Loss on sub_epoch 11/30: 6344.993722098215
# Loss on sub_epoch 21/30: 6378.983677455357
# Updating lr
# On epoch 4/10 average loss = 6327.873637462798, purity = 0.69125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6303.714913504465
# Loss on sub_epoch 11/30: 6249.7119140625
# Loss on sub_epoch 21/30: 6358.574846540178
# Updating lr
# On epoch 5/10 average loss = 6307.622819010417, purity = 0.67625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6288.028250558035
# Loss on sub_epoch 11/30: 6318.205287388393
# Loss on sub_epoch 21/30: 6324.27978515625
# Updating lr
# On epoch 6/10 average loss = 6325.322256324404, purity = 0.66125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6326.694614955357
# Loss on sub_epoch 11/30: 6296.77099609375
# Loss on sub_epoch 21/30: 6395.113141741072
# Updating lr
# On epoch 7/10 average loss = 6323.016203962054, purity = 0.65375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6316.766671316965
# Loss on sub_epoch 11/30: 6344.965750558035
# Loss on sub_epoch 21/30: 6382.498744419643
# On epoch 8/10 average loss = 6315.519833519345, purity = 0.6475
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6316.075265066965
# Updating lr
# Loss on sub_epoch 11/30: 6383.502092633928
# Loss on sub_epoch 21/30: 6378.289341517857
# On epoch 9/10 average loss = 6322.874546595982, purity = 0.6425000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6352.919991629465
# Updating lr
# Loss on sub_epoch 11/30: 6294.325055803572
# Loss on sub_epoch 21/30: 6294.874930245535
# On epoch 10/10 average loss = 6324.25181594122, purity = 0.63625
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.65
# Beginning m-step
# Loss on sub_epoch 1/30: 8515.458426339286
# Loss on sub_epoch 11/30: 7031.565778459822
# Loss on sub_epoch 21/30: 6734.129255022322
# On epoch 1/10 average loss = 6972.509579613095, purity = 0.56375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6573.384486607143
# Loss on sub_epoch 11/30: 6426.992257254465
# Updating lr
# Loss on sub_epoch 21/30: 6322.929338727678
# On epoch 2/10 average loss = 6430.453655133929, purity = 0.50625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6318.704171316965
# Loss on sub_epoch 11/30: 6267.836844308035
# Updating lr
# Loss on sub_epoch 21/30: 6296.695521763393
# On epoch 3/10 average loss = 6317.673563058036, purity = 0.5487500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6306.8974609375
# Loss on sub_epoch 11/30: 6300.314662388393
# Updating lr
# Loss on sub_epoch 21/30: 6192.833286830357
# On epoch 4/10 average loss = 6266.736493210566, purity = 0.565
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6228.367327008928
# Loss on sub_epoch 11/30: 6364.627301897322
# Updating lr
# Loss on sub_epoch 21/30: 6199.090890066965
# On epoch 5/10 average loss = 6256.099846540179, purity = 0.565
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6188.650181361607
# Loss on sub_epoch 11/30: 6254.0322265625
# Updating lr
# Loss on sub_epoch 21/30: 6273.787458147322
# On epoch 6/10 average loss = 6262.953141276042, purity = 0.56625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6227.652273995535
# Loss on sub_epoch 11/30: 6306.902204241072
# Updating lr
# Loss on sub_epoch 21/30: 6237.066196986607
# On epoch 7/10 average loss = 6265.273186383929, purity = 0.565
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6221.220005580357
# Loss on sub_epoch 11/30: 6145.771205357143
# Updating lr
# Loss on sub_epoch 21/30: 6212.700892857143
# On epoch 8/10 average loss = 6259.356640625, purity = 0.56625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6243.972377232143
# Loss on sub_epoch 11/30: 6216.834681919643
# Updating lr
# Loss on sub_epoch 21/30: 6267.769601004465
# On epoch 9/10 average loss = 6250.254924665179, purity = 0.56625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6251.75390625
# Loss on sub_epoch 11/30: 6238.750418526785
# Loss on sub_epoch 21/30: 6198.521344866072
# Updating lr
# On epoch 10/10 average loss = 6255.191401599703, purity = 0.56625
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.58125
# Beginning m-step
# Loss on sub_epoch 1/30: 8582.82972935268
# Loss on sub_epoch 11/30: 7048.546526227678
# Loss on sub_epoch 21/30: 6712.087123325893
# On epoch 1/10 average loss = 6992.533510044643, purity = 0.51875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6626.097028459822
# Loss on sub_epoch 11/30: 6424.03173828125
# Updating lr
# Loss on sub_epoch 21/30: 6452.72509765625
# On epoch 2/10 average loss = 6458.073567708333, purity = 0.58875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6399.85302734375
# Loss on sub_epoch 11/30: 6357.452218191965
# Updating lr
# Loss on sub_epoch 21/30: 6314.155343191965
# On epoch 3/10 average loss = 6360.032603236607, purity = 0.59
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6265.348284040178
# Loss on sub_epoch 11/30: 6302.521344866072
# Updating lr
# Loss on sub_epoch 21/30: 6272.2412109375
# On epoch 4/10 average loss = 6320.71144438244, purity = 0.5975
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6272.207589285715
# Loss on sub_epoch 11/30: 6283.802873883928
# Updating lr
# Loss on sub_epoch 21/30: 6296.335518973215
# On epoch 5/10 average loss = 6293.960167875744, purity = 0.6000000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6268.619559151785
# Loss on sub_epoch 11/30: 6268.447195870535
# Updating lr
# Loss on sub_epoch 21/30: 6184.134974888393
# On epoch 6/10 average loss = 6292.37712983631, purity = 0.5962500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6327.61328125
# Loss on sub_epoch 11/30: 6283.005231584822
# Loss on sub_epoch 21/30: 6279.46728515625
# Updating lr
# On epoch 7/10 average loss = 6293.480929129464, purity = 0.59625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6286.627650669643
# Loss on sub_epoch 11/30: 6339.251953125
# Loss on sub_epoch 21/30: 6279.597307477678
# Updating lr
# On epoch 8/10 average loss = 6277.7262881324405, purity = 0.59625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6280.822474888393
# Loss on sub_epoch 11/30: 6296.017717633928
# Updating lr
# Loss on sub_epoch 21/30: 6341.467912946428
# On epoch 9/10 average loss = 6287.923077101935, purity = 0.59625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6319.141950334822
# Loss on sub_epoch 11/30: 6262.807547433035
# Updating lr
# Loss on sub_epoch 21/30: 6309.264927455357
# On epoch 10/10 average loss = 6293.796556454613, purity = 0.59625
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.665
# Beginning m-step
# Loss on sub_epoch 1/30: 8746.523158482143
# Loss on sub_epoch 11/30: 6924.324497767857
# Loss on sub_epoch 21/30: 6833.310267857143
# On epoch 1/10 average loss = 6992.599760509673, purity = 0.6525000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6613.774483816965
# Loss on sub_epoch 11/30: 6465.000209263393
# Updating lr
# Loss on sub_epoch 21/30: 6353.604282924107
# On epoch 2/10 average loss = 6451.063134765625, purity = 0.6525000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6376.538155691965
# Loss on sub_epoch 11/30: 6362.906877790178
# Updating lr
# Loss on sub_epoch 21/30: 6337.20361328125
# On epoch 3/10 average loss = 6326.88767671131, purity = 0.65
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6248.757533482143
# Loss on sub_epoch 11/30: 6223.760672433035
# Loss on sub_epoch 21/30: 6298.370326450893
# Updating lr
# On epoch 4/10 average loss = 6278.333665829613, purity = 0.65
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6313.406040736607
# Loss on sub_epoch 11/30: 6263.701799665178
# Loss on sub_epoch 21/30: 6225.895647321428
# Updating lr
# On epoch 5/10 average loss = 6262.176034691221, purity = 0.6425
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6285.545828683035
# Loss on sub_epoch 11/30: 6246.289132254465
# Loss on sub_epoch 21/30: 6238.461844308035
# Updating lr
# On epoch 6/10 average loss = 6263.106061662947, purity = 0.64625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6227.412109375
# Loss on sub_epoch 11/30: 6289.095005580357
# Loss on sub_epoch 21/30: 6268.738141741072
# Updating lr
# On epoch 7/10 average loss = 6267.398209635417, purity = 0.6487499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6253.246930803572
# Loss on sub_epoch 11/30: 6150.667061941965
# Loss on sub_epoch 21/30: 6190.692313058035
# Updating lr
# On epoch 8/10 average loss = 6265.894254557292, purity = 0.6487499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6351.58837890625
# Loss on sub_epoch 11/30: 6268.307826450893
# Loss on sub_epoch 21/30: 6211.0
# Updating lr
# On epoch 9/10 average loss = 6273.186511811756, purity = 0.6475
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6256.526785714285
# Loss on sub_epoch 11/30: 6198.145159040178
# Loss on sub_epoch 21/30: 6225.744001116072
# Updating lr
# On epoch 10/10 average loss = 6253.702553013393, purity = 0.6475
# div: 16 0.62475 +- 0.0432391604913879
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.52875
# Beginning m-step
# Loss on sub_epoch 1/30: 9094.08314732143
# Loss on sub_epoch 11/30: 6831.054757254465
# Loss on sub_epoch 21/30: 6405.543247767857
# On epoch 1/10 average loss = 6854.181468563988, purity = 0.55375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6339.809291294643
# Loss on sub_epoch 11/30: 6053.508928571428
# Updating lr
# Loss on sub_epoch 21/30: 6034.184291294643
# On epoch 2/10 average loss = 6077.624267578125, purity = 0.5750000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5968.509556361607
# Loss on sub_epoch 11/30: 5906.089215959822
# Updating lr
# Loss on sub_epoch 21/30: 5940.215122767857
# On epoch 3/10 average loss = 5958.457628813244, purity = 0.605
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5945.893205915178
# Loss on sub_epoch 11/30: 5926.463727678572
# Loss on sub_epoch 21/30: 5935.397670200893
# Updating lr
# On epoch 4/10 average loss = 5946.644273158482, purity = 0.6125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5902.258649553572
# Loss on sub_epoch 11/30: 5948.286063058035
# Loss on sub_epoch 21/30: 5970.801478794643
# Updating lr
# On epoch 5/10 average loss = 5935.809484281994, purity = 0.615
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5949.39404296875
# Loss on sub_epoch 11/30: 5936.532156808035
# Loss on sub_epoch 21/30: 5912.670479910715
# Updating lr
# On epoch 6/10 average loss = 5935.437734840029, purity = 0.6125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5922.284877232143
# Loss on sub_epoch 11/30: 5922.80029296875
# Loss on sub_epoch 21/30: 6015.800502232143
# Updating lr
# On epoch 7/10 average loss = 5941.174876767113, purity = 0.6175
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5945.210797991072
# Loss on sub_epoch 11/30: 5953.944475446428
# Loss on sub_epoch 21/30: 5929.879324776785
# Updating lr
# On epoch 8/10 average loss = 5949.533977399554, purity = 0.6175
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5942.265415736607
# Loss on sub_epoch 11/30: 5988.185616629465
# Loss on sub_epoch 21/30: 5894.617815290178
# Updating lr
# On epoch 9/10 average loss = 5928.921909877232, purity = 0.615
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5892.02490234375
# Loss on sub_epoch 11/30: 5940.09228515625
# Loss on sub_epoch 21/30: 5887.549176897322
# On epoch 10/10 average loss = 5942.82341889881, purity = 0.61375
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.51375
# Beginning m-step
# Loss on sub_epoch 1/30: 9278.894810267857
# Loss on sub_epoch 11/30: 6783.529924665178
# Loss on sub_epoch 21/30: 6403.173688616072
# On epoch 1/10 average loss = 6872.657786923363, purity = 0.57875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6219.632463727678
# Loss on sub_epoch 11/30: 6182.254534040178
# Loss on sub_epoch 21/30: 6005.264369419643
# Updating lr
# On epoch 2/10 average loss = 6080.505022321428, purity = 0.59375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5995.279296875
# Loss on sub_epoch 11/30: 5939.613490513393
# Loss on sub_epoch 21/30: 5966.826939174107
# Updating lr
# On epoch 3/10 average loss = 5921.8537155877975, purity = 0.60875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5918.416085379465
# Loss on sub_epoch 11/30: 5910.93359375
# Updating lr
# Loss on sub_epoch 21/30: 5896.714913504465
# On epoch 4/10 average loss = 5911.487041945685, purity = 0.61875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5850.641531808035
# Loss on sub_epoch 11/30: 5861.271135602678
# Loss on sub_epoch 21/30: 5838.797921316965
# Updating lr
# On epoch 5/10 average loss = 5895.458024088542, purity = 0.6212500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5865.638323102678
# Loss on sub_epoch 11/30: 5926.630929129465
# Updating lr
# Loss on sub_epoch 21/30: 5868.767229352678
# On epoch 6/10 average loss = 5895.81525297619, purity = 0.6225
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5971.363071986607
# Loss on sub_epoch 11/30: 5951.018763950893
# Updating lr
# Loss on sub_epoch 21/30: 5895.839983258928
# On epoch 7/10 average loss = 5903.093884858631, purity = 0.6275
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5830.742745535715
# Loss on sub_epoch 11/30: 5864.240025111607
# Updating lr
# Loss on sub_epoch 21/30: 5893.258231026785
# On epoch 8/10 average loss = 5894.868726748512, purity = 0.62875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5876.748465401785
# Loss on sub_epoch 11/30: 5938.335100446428
# Updating lr
# Loss on sub_epoch 21/30: 5916.998046875
# On epoch 9/10 average loss = 5895.46722702753, purity = 0.62875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5871.012625558035
# Loss on sub_epoch 11/30: 5889.806291852678
# Updating lr
# Loss on sub_epoch 21/30: 5901.800083705357
# On epoch 10/10 average loss = 5893.286951264881, purity = 0.63
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.505
# Beginning m-step
# Loss on sub_epoch 1/30: 9407.680106026786
# Loss on sub_epoch 11/30: 6841.650530133928
# Loss on sub_epoch 21/30: 6523.333356584822
# On epoch 1/10 average loss = 6964.319852120536, purity = 0.60875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6229.772809709822
# Loss on sub_epoch 11/30: 6236.946358816965
# Loss on sub_epoch 21/30: 6060.071847098215
# Updating lr
# On epoch 2/10 average loss = 6152.9868466331845, purity = 0.6325000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5991.047154017857
# Loss on sub_epoch 11/30: 5965.223074776785
# Loss on sub_epoch 21/30: 6044.256766183035
# Updating lr
# On epoch 3/10 average loss = 5986.789311290922, purity = 0.69875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5956.077078683035
# Loss on sub_epoch 11/30: 5968.168805803572
# Updating lr
# Loss on sub_epoch 21/30: 6009.9599609375
# On epoch 4/10 average loss = 5979.624474516369, purity = 0.7150000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5925.889090401785
# Loss on sub_epoch 11/30: 6037.251674107143
# Updating lr
# Loss on sub_epoch 21/30: 6002.5390625
# On epoch 5/10 average loss = 5979.709026227679, purity = 0.70875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5970.326799665178
# Loss on sub_epoch 11/30: 5924.859514508928
# Updating lr
# Loss on sub_epoch 21/30: 5982.339983258928
# On epoch 6/10 average loss = 5977.187932477678, purity = 0.7050000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5961.797642299107
# Loss on sub_epoch 11/30: 5958.249581473215
# Updating lr
# Loss on sub_epoch 21/30: 5925.862444196428
# On epoch 7/10 average loss = 5975.337811569941, purity = 0.69875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5978.103236607143
# Loss on sub_epoch 11/30: 5959.8828125
# Loss on sub_epoch 21/30: 5917.912318638393
# Updating lr
# On epoch 8/10 average loss = 5981.252966889881, purity = 0.6925
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5941.744768415178
# Loss on sub_epoch 11/30: 6074.16552734375
# Loss on sub_epoch 21/30: 5957.066057477678
# Updating lr
# On epoch 9/10 average loss = 5978.110081845238, purity = 0.68875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5955.158342633928
# Loss on sub_epoch 11/30: 5968.412876674107
# Loss on sub_epoch 21/30: 6057.572335379465
# Updating lr
# On epoch 10/10 average loss = 5986.2789341517855, purity = 0.685
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.55125
# Beginning m-step
# Loss on sub_epoch 1/30: 8983.97767857143
# Loss on sub_epoch 11/30: 6775.916434151785
# Loss on sub_epoch 21/30: 6461.139020647322
# On epoch 1/10 average loss = 6801.9412876674105, purity = 0.54
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6191.976283482143
# Loss on sub_epoch 11/30: 6099.279436383928
# Updating lr
# Loss on sub_epoch 21/30: 5985.3310546875
# On epoch 2/10 average loss = 6050.0750697544645, purity = 0.505
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5947.030064174107
# Loss on sub_epoch 11/30: 6007.542550223215
# Updating lr
# Loss on sub_epoch 21/30: 5993.500139508928
# On epoch 3/10 average loss = 5983.521400669643, purity = 0.52625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5958.736676897322
# Loss on sub_epoch 11/30: 5959.369907924107
# Updating lr
# Loss on sub_epoch 21/30: 5926.1083984375
# On epoch 4/10 average loss = 5962.023232886905, purity = 0.5425
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5968.393624441965
# Loss on sub_epoch 11/30: 6000.995884486607
# Updating lr
# Loss on sub_epoch 21/30: 5911.783342633928
# On epoch 5/10 average loss = 5949.900662667411, purity = 0.54625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5923.351911272322
# Loss on sub_epoch 11/30: 5964.820242745535
# Updating lr
# Loss on sub_epoch 21/30: 5944.175851004465
# On epoch 6/10 average loss = 5944.9374697730655, purity = 0.5487500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5939.552943638393
# Loss on sub_epoch 11/30: 5953.481166294643
# Updating lr
# Loss on sub_epoch 21/30: 5913.468540736607
# On epoch 7/10 average loss = 5951.918982514881, purity = 0.55
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5842.927315848215
# Loss on sub_epoch 11/30: 5976.726353236607
# Updating lr
# Loss on sub_epoch 21/30: 5925.119210379465
# On epoch 8/10 average loss = 5937.813395182292, purity = 0.54625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5919.705217633928
# Loss on sub_epoch 11/30: 5948.357282366072
# Updating lr
# Loss on sub_epoch 21/30: 5969.379534040178
# On epoch 9/10 average loss = 5932.412746465774, purity = 0.54375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5909.457380022322
# Loss on sub_epoch 11/30: 6018.666155133928
# Updating lr
# Loss on sub_epoch 21/30: 5992.078683035715
# On epoch 10/10 average loss = 5949.945061383929, purity = 0.545
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.6125
# Beginning m-step
# Loss on sub_epoch 1/30: 9317.97572544643
# Loss on sub_epoch 11/30: 6806.5419921875
# Loss on sub_epoch 21/30: 6362.951520647322
# On epoch 1/10 average loss = 6888.003896949404, purity = 0.52125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6232.47021484375
# Loss on sub_epoch 11/30: 6137.925362723215
# Updating lr
# Loss on sub_epoch 21/30: 6035.224190848215
# On epoch 2/10 average loss = 6113.277580915179, purity = 0.57375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6024.247488839285
# Loss on sub_epoch 11/30: 6096.5078125
# Updating lr
# Loss on sub_epoch 21/30: 6027.856515066965
# On epoch 3/10 average loss = 6009.408956473214, purity = 0.59125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6035.887834821428
# Loss on sub_epoch 11/30: 5938.136579241072
# Updating lr
# Loss on sub_epoch 21/30: 5931.856863839285
# On epoch 4/10 average loss = 5989.890741257441, purity = 0.6100000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6011.755859375
# Loss on sub_epoch 11/30: 5934.712890625
# Updating lr
# Loss on sub_epoch 21/30: 5917.730398995535
# On epoch 5/10 average loss = 5976.18656296503, purity = 0.61375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5993.197265625
# Loss on sub_epoch 11/30: 5911.352887834822
# Updating lr
# Loss on sub_epoch 21/30: 5948.304338727678
# On epoch 6/10 average loss = 5980.451776413691, purity = 0.61
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 6041.585170200893
# Loss on sub_epoch 11/30: 5967.392508370535
# Updating lr
# Loss on sub_epoch 21/30: 5978.804896763393
# On epoch 7/10 average loss = 5976.2143996465775, purity = 0.6125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5985.547991071428
# Loss on sub_epoch 11/30: 6094.401018415178
# Updating lr
# Loss on sub_epoch 21/30: 5977.033342633928
# On epoch 8/10 average loss = 5977.19966750372, purity = 0.60375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5972.125069754465
# Loss on sub_epoch 11/30: 5949.8544921875
# Updating lr
# Loss on sub_epoch 21/30: 5982.203543526785
# On epoch 9/10 average loss = 5982.1084286644345, purity = 0.605
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5977.476702008928
# Loss on sub_epoch 11/30: 5923.514508928572
# Updating lr
# Loss on sub_epoch 21/30: 5944.192103794643
# On epoch 10/10 average loss = 5965.9404808407735, purity = 0.605
# div: 32 0.6252500000000001 +- 0.05278730908087664
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.505
# Beginning m-step
# Loss on sub_epoch 1/30: 8962.43959263393
# Loss on sub_epoch 11/30: 6481.652622767857
# Loss on sub_epoch 21/30: 6046.843610491072
# On epoch 1/10 average loss = 6572.07943405878, purity = 0.5375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5866.16162109375
# Loss on sub_epoch 11/30: 5610.577078683035
# Loss on sub_epoch 21/30: 5538.006905691965
# Updating lr
# On epoch 2/10 average loss = 5640.9639857700895, purity = 0.52625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5495.860979352678
# Loss on sub_epoch 11/30: 5470.958077566965
# Updating lr
# Loss on sub_epoch 21/30: 5516.91455078125
# On epoch 3/10 average loss = 5503.858470517113, purity = 0.5475000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5493.752092633928
# Loss on sub_epoch 11/30: 5520.498465401785
# Loss on sub_epoch 21/30: 5533.584333147322
# Updating lr
# On epoch 4/10 average loss = 5490.455364118304, purity = 0.5487500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5483.2119140625
# Loss on sub_epoch 11/30: 5509.375697544643
# Loss on sub_epoch 21/30: 5500.519740513393
# Updating lr
# On epoch 5/10 average loss = 5482.59439406622, purity = 0.55125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5477.536551339285
# Loss on sub_epoch 11/30: 5514.509626116072
# Loss on sub_epoch 21/30: 5531.01318359375
# Updating lr
# On epoch 6/10 average loss = 5497.852627418155, purity = 0.55375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5400.020368303572
# Loss on sub_epoch 11/30: 5462.060686383928
# Loss on sub_epoch 21/30: 5440.98779296875
# On epoch 7/10 average loss = 5481.133461216518, purity = 0.5525
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5429.812290736607
# Updating lr
# Loss on sub_epoch 11/30: 5521.606096540178
# Loss on sub_epoch 21/30: 5484.482282366072
# On epoch 8/10 average loss = 5485.494401041667, purity = 0.55375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5543.254743303572
# Updating lr
# Loss on sub_epoch 11/30: 5447.241071428572
# Loss on sub_epoch 21/30: 5502.776018415178
# On epoch 9/10 average loss = 5493.835223679315, purity = 0.55625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5419.337123325893
# Loss on sub_epoch 11/30: 5516.781598772322
# Updating lr
# Loss on sub_epoch 21/30: 5549.554408482143
# On epoch 10/10 average loss = 5488.256161644345, purity = 0.55375
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.5575
# Beginning m-step
# Loss on sub_epoch 1/30: 8974.036900111607
# Loss on sub_epoch 11/30: 6497.479352678572
# Loss on sub_epoch 21/30: 6017.610909598215
# On epoch 1/10 average loss = 6557.290246000744, purity = 0.54375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5832.192731584822
# Loss on sub_epoch 11/30: 5670.426967075893
# Loss on sub_epoch 21/30: 5550.421595982143
# Updating lr
# On epoch 2/10 average loss = 5650.274207124256, purity = 0.585
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5562.024135044643
# Loss on sub_epoch 11/30: 5470.369768415178
# Loss on sub_epoch 21/30: 5466.153738839285
# On epoch 3/10 average loss = 5492.736353701637, purity = 0.585
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5435.215541294643
# Updating lr
# Loss on sub_epoch 11/30: 5520.067592075893
# Loss on sub_epoch 21/30: 5485.594796316965
# On epoch 4/10 average loss = 5460.876808965774, purity = 0.5900000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5453.541294642857
# Updating lr
# Loss on sub_epoch 11/30: 5451.224400111607
# Loss on sub_epoch 21/30: 5441.264787946428
# On epoch 5/10 average loss = 5465.626292782738, purity = 0.5975
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5451.363839285715
# Updating lr
# Loss on sub_epoch 11/30: 5453.714285714285
# Loss on sub_epoch 21/30: 5441.985072544643
# Updating lr
# On epoch 6/10 average loss = 5461.491631789435, purity = 0.5975
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5481.790318080357
# Loss on sub_epoch 11/30: 5490.260881696428
# Loss on sub_epoch 21/30: 5459.59033203125
# On epoch 7/10 average loss = 5464.448030598958, purity = 0.59625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5407.782924107143
# Updating lr
# Loss on sub_epoch 11/30: 5388.732352120535
# Loss on sub_epoch 21/30: 5480.348563058035
# On epoch 8/10 average loss = 5447.61484375, purity = 0.59875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Updating lr
# Loss on sub_epoch 1/30: 5463.200055803572
# Loss on sub_epoch 11/30: 5437.568638392857
# Loss on sub_epoch 21/30: 5510.540108816965
# On epoch 9/10 average loss = 5463.361946614584, purity = 0.59875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5389.380580357143
# Updating lr
# Loss on sub_epoch 11/30: 5478.017229352678
# Loss on sub_epoch 21/30: 5420.859723772322
# On epoch 10/10 average loss = 5462.185349237351, purity = 0.59375
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.5850000000000001
# Beginning m-step
# Loss on sub_epoch 1/30: 8823.92466517857
# Loss on sub_epoch 11/30: 6531.515206473215
# Loss on sub_epoch 21/30: 6067.765276227678
# On epoch 1/10 average loss = 6581.796800595238, purity = 0.6775
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5864.031808035715
# Loss on sub_epoch 11/30: 5734.88427734375
# Loss on sub_epoch 21/30: 5591.860770089285
# Updating lr
# On epoch 2/10 average loss = 5671.284709821429, purity = 0.6812499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5492.6640625
# Loss on sub_epoch 11/30: 5532.079520089285
# Loss on sub_epoch 21/30: 5457.401227678572
# Updating lr
# On epoch 3/10 average loss = 5512.645135788691, purity = 0.70625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5450.796107700893
# Loss on sub_epoch 11/30: 5466.924037388393
# Loss on sub_epoch 21/30: 5503.318777901785
# Updating lr
# On epoch 4/10 average loss = 5505.459349423363, purity = 0.7375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5466.022739955357
# Loss on sub_epoch 11/30: 5517.821010044643
# Loss on sub_epoch 21/30: 5466.431710379465
# Updating lr
# On epoch 5/10 average loss = 5496.062132626488, purity = 0.73
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5485.499372209822
# Loss on sub_epoch 11/30: 5538.456403459822
# Updating lr
# Loss on sub_epoch 21/30: 5533.547014508928
# On epoch 6/10 average loss = 5503.6970447358635, purity = 0.7250000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5470.337820870535
# Loss on sub_epoch 11/30: 5418.417759486607
# Loss on sub_epoch 21/30: 5537.43115234375
# Updating lr
# On epoch 7/10 average loss = 5489.3555129278275, purity = 0.72125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5505.249302455357
# Loss on sub_epoch 11/30: 5486.061872209822
# Loss on sub_epoch 21/30: 5460.460379464285
# Updating lr
# On epoch 8/10 average loss = 5506.46662248884, purity = 0.7
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5532.894740513393
# Loss on sub_epoch 11/30: 5524.655831473215
# Loss on sub_epoch 21/30: 5472.728306361607
# Updating lr
# On epoch 9/10 average loss = 5494.918605840774, purity = 0.69
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5532.915876116072
# Loss on sub_epoch 11/30: 5529.728864397322
# Loss on sub_epoch 21/30: 5458.386300223215
# Updating lr
# On epoch 10/10 average loss = 5510.493159412203, purity = 0.685
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.51125
# Beginning m-step
# Loss on sub_epoch 1/30: 8593.709402901786
# Loss on sub_epoch 11/30: 6491.088797433035
# Loss on sub_epoch 21/30: 6052.085239955357
# On epoch 1/10 average loss = 6461.08251953125, purity = 0.55125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5805.244489397322
# Loss on sub_epoch 11/30: 5748.06982421875
# Updating lr
# Loss on sub_epoch 21/30: 5571.504115513393
# On epoch 2/10 average loss = 5637.611139787947, purity = 0.5625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5568.176409040178
# Loss on sub_epoch 11/30: 5541.740862165178
# Loss on sub_epoch 21/30: 5534.094377790178
# Updating lr
# On epoch 3/10 average loss = 5524.480396670387, purity = 0.5775
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5536.795689174107
# Loss on sub_epoch 11/30: 5492.331891741072
# Updating lr
# Loss on sub_epoch 21/30: 5535.125069754465
# On epoch 4/10 average loss = 5508.357468377976, purity = 0.57625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5593.580287388393
# Loss on sub_epoch 11/30: 5477.658272879465
# Loss on sub_epoch 21/30: 5527.411690848215
# Updating lr
# On epoch 5/10 average loss = 5508.611381603423, purity = 0.57
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5479.413504464285
# Loss on sub_epoch 11/30: 5545.844866071428
# Loss on sub_epoch 21/30: 5520.18701171875
# Updating lr
# On epoch 6/10 average loss = 5505.3816220238095, purity = 0.57375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5480.634905133928
# Loss on sub_epoch 11/30: 5537.573102678572
# Updating lr
# Loss on sub_epoch 21/30: 5544.246651785715
# On epoch 7/10 average loss = 5507.809793526786, purity = 0.57125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5474.232142857143
# Loss on sub_epoch 11/30: 5522.159388950893
# Loss on sub_epoch 21/30: 5433.804896763393
# Updating lr
# On epoch 8/10 average loss = 5522.694587053571, purity = 0.5700000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5492.684919084822
# Loss on sub_epoch 11/30: 5532.507603236607
# Loss on sub_epoch 21/30: 5474.547781808035
# Updating lr
# On epoch 9/10 average loss = 5512.596589006696, purity = 0.56625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5581.108468191965
# Loss on sub_epoch 11/30: 5498.510602678572
# Loss on sub_epoch 21/30: 5576.416085379465
# Updating lr
# On epoch 10/10 average loss = 5507.486228143601, purity = 0.56625
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.525
# Beginning m-step
# Loss on sub_epoch 1/30: 8756.229771205357
# Loss on sub_epoch 11/30: 6536.570242745535
# Loss on sub_epoch 21/30: 6075.13037109375
# On epoch 1/10 average loss = 6528.214439174107, purity = 0.59625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5826.258440290178
# Loss on sub_epoch 11/30: 5717.508440290178
# Loss on sub_epoch 21/30: 5571.051339285715
# Updating lr
# On epoch 2/10 average loss = 5677.184749348959, purity = 0.52375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5621.624232700893
# Loss on sub_epoch 11/30: 5522.974679129465
# Loss on sub_epoch 21/30: 5473.606863839285
# Updating lr
# On epoch 3/10 average loss = 5517.012960379464, purity = 0.50875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5530.89208984375
# Loss on sub_epoch 11/30: 5565.971888950893
# Loss on sub_epoch 21/30: 5524.715750558035
# Updating lr
# On epoch 4/10 average loss = 5518.517678106399, purity = 0.5025
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5493.981724330357
# Loss on sub_epoch 11/30: 5536.50439453125
# Loss on sub_epoch 21/30: 5506.226004464285
# Updating lr
# On epoch 5/10 average loss = 5516.739088076637, purity = 0.505
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5519.68017578125
# Loss on sub_epoch 11/30: 5531.028111049107
# Loss on sub_epoch 21/30: 5486.171247209822
# Updating lr
# On epoch 6/10 average loss = 5513.72623000372, purity = 0.50375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5551.170479910715
# Loss on sub_epoch 11/30: 5498.862583705357
# Loss on sub_epoch 21/30: 5546.381556919643
# Updating lr
# On epoch 7/10 average loss = 5514.347298177084, purity = 0.5137499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5509.970145089285
# Loss on sub_epoch 11/30: 5520.555943080357
# Loss on sub_epoch 21/30: 5511.840401785715
# Updating lr
# On epoch 8/10 average loss = 5500.970807756697, purity = 0.51375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5550.60888671875
# Loss on sub_epoch 11/30: 5528.162109375
# Loss on sub_epoch 21/30: 5492.530970982143
# Updating lr
# On epoch 9/10 average loss = 5506.747533017113, purity = 0.51625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5471.170758928572
# Loss on sub_epoch 11/30: 5522.594517299107
# Loss on sub_epoch 21/30: 5428.064453125
# Updating lr
# On epoch 10/10 average loss = 5502.271675037202, purity = 0.52
# div: 64 0.6132500000000001 +- 0.06397558127910993
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.525
# Beginning m-step
# Loss on sub_epoch 1/30: 8987.901925223214
# Loss on sub_epoch 11/30: 6300.13525390625
# Loss on sub_epoch 21/30: 5750.820452008928
# On epoch 1/10 average loss = 6370.974834914435, purity = 0.635
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5486.808942522322
# Loss on sub_epoch 11/30: 5329.388532366072
# Loss on sub_epoch 21/30: 5241.965471540178
# Updating lr
# On epoch 2/10 average loss = 5302.32456984747, purity = 0.64125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5165.001046316965
# Loss on sub_epoch 11/30: 5224.572126116072
# Loss on sub_epoch 21/30: 5174.5927734375
# Updating lr
# On epoch 3/10 average loss = 5162.987897600447, purity = 0.64625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5138.61572265625
# Loss on sub_epoch 11/30: 5159.974748883928
# Loss on sub_epoch 21/30: 5145.529854910715
# Updating lr
# On epoch 4/10 average loss = 5157.410065569196, purity = 0.6775
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5185.329171316965
# Loss on sub_epoch 11/30: 5033.819893973215
# Updating lr
# Loss on sub_epoch 21/30: 5214.6640625
# On epoch 5/10 average loss = 5154.5782435825895, purity = 0.6875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5105.902413504465
# Loss on sub_epoch 11/30: 5133.795549665178
# Loss on sub_epoch 21/30: 5042.567522321428
# Updating lr
# On epoch 6/10 average loss = 5141.48519577753, purity = 0.6950000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5108.515694754465
# Loss on sub_epoch 11/30: 5165.078404017857
# Loss on sub_epoch 21/30: 5102.945033482143
# On epoch 7/10 average loss = 5150.990169270834, purity = 0.7
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5146.268903459822
# Updating lr
# Loss on sub_epoch 11/30: 5133.274065290178
# Loss on sub_epoch 21/30: 5186.793387276785
# On epoch 8/10 average loss = 5149.470728701637, purity = 0.70625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5070.410086495535
# Updating lr
# Loss on sub_epoch 11/30: 5150.056012834822
# Loss on sub_epoch 21/30: 5222.484026227678
# Updating lr
# On epoch 9/10 average loss = 5151.461860584077, purity = 0.7137500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5241.4814453125
# Loss on sub_epoch 11/30: 5198.234793526785
# Loss on sub_epoch 21/30: 5132.384137834822
# On epoch 10/10 average loss = 5154.430817522321, purity = 0.725
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.55
# Beginning m-step
# Loss on sub_epoch 1/30: 8851.543387276786
# Loss on sub_epoch 11/30: 6266.490862165178
# Loss on sub_epoch 21/30: 5766.886509486607
# On epoch 1/10 average loss = 6323.3530715215775, purity = 0.6425000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5471.498465401785
# Loss on sub_epoch 11/30: 5317.808175223215
# Updating lr
# Loss on sub_epoch 21/30: 5269.739536830357
# On epoch 2/10 average loss = 5310.91861281622, purity = 0.68125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5195.476492745535
# Loss on sub_epoch 11/30: 5162.294015066965
# Updating lr
# Loss on sub_epoch 21/30: 5220.699776785715
# On epoch 3/10 average loss = 5173.914822823661, purity = 0.73875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5183.925990513393
# Loss on sub_epoch 11/30: 5206.630510602678
# Updating lr
# Loss on sub_epoch 21/30: 5123.081682477678
# On epoch 4/10 average loss = 5180.8324753534225, purity = 0.78
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5164.161760602678
# Loss on sub_epoch 11/30: 5237.153180803572
# Updating lr
# Loss on sub_epoch 21/30: 5259.517857142857
# On epoch 5/10 average loss = 5179.129543340774, purity = 0.79
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5151.683454241072
# Loss on sub_epoch 11/30: 5189.296595982143
# Updating lr
# Loss on sub_epoch 21/30: 5184.680594308035
# On epoch 6/10 average loss = 5175.925367373512, purity = 0.7887500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5197.47900390625
# Loss on sub_epoch 11/30: 5210.851492745535
# Loss on sub_epoch 21/30: 5126.452497209822
# Updating lr
# On epoch 7/10 average loss = 5178.700360398066, purity = 0.7925
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5185.174037388393
# Loss on sub_epoch 11/30: 5225.268624441965
# Loss on sub_epoch 21/30: 5234.874790736607
# Updating lr
# On epoch 8/10 average loss = 5191.015211123512, purity = 0.7925
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5088.189313616072
# Loss on sub_epoch 11/30: 5189.379603794643
# Loss on sub_epoch 21/30: 5073.728236607143
# Updating lr
# On epoch 9/10 average loss = 5157.982400948661, purity = 0.7949999999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5237.6533203125
# Loss on sub_epoch 11/30: 5181.043736049107
# Loss on sub_epoch 21/30: 5156.215750558035
# Updating lr
# On epoch 10/10 average loss = 5182.363520740328, purity = 0.7949999999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.52375
# Beginning m-step
# Loss on sub_epoch 1/30: 8663.746372767857
# Loss on sub_epoch 11/30: 6265.913992745535
# Loss on sub_epoch 21/30: 5772.272181919643
# On epoch 1/10 average loss = 6290.527155412947, purity = 0.52625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5472.27734375
# Loss on sub_epoch 11/30: 5386.900948660715
# Loss on sub_epoch 21/30: 5251.1630859375
# Updating lr
# On epoch 2/10 average loss = 5289.4896484375, purity = 0.6575
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5082.318568638393
# Loss on sub_epoch 11/30: 5165.486397879465
# Loss on sub_epoch 21/30: 5177.972237723215
# On epoch 3/10 average loss = 5119.837400018601, purity = 0.7050000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Updating lr
# Loss on sub_epoch 1/30: 5122.900809151785
# Loss on sub_epoch 11/30: 5039.575613839285
# Loss on sub_epoch 21/30: 5126.867954799107
# Updating lr
# On epoch 4/10 average loss = 5116.178364490327, purity = 0.76875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5056.354352678572
# Loss on sub_epoch 11/30: 5163.963588169643
# Loss on sub_epoch 21/30: 5072.835518973215
# Updating lr
# On epoch 5/10 average loss = 5101.710535249256, purity = 0.7675000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5110.546316964285
# Loss on sub_epoch 11/30: 5122.402971540178
# Loss on sub_epoch 21/30: 5088.719168526785
# Updating lr
# On epoch 6/10 average loss = 5114.15884719122, purity = 0.7625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# ...
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5147.4931640625
# Loss on sub_epoch 11/30: 5102.089285714285
# Loss on sub_epoch 21/30: 5193.540178571428
# Updating lr
# On epoch 4/10 average loss = 5139.3960402715775, purity = 0.54
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5149.771135602678
# Loss on sub_epoch 11/30: 5160.818359375
# Loss on sub_epoch 21/30: 5166.276018415178
# Updating lr
# On epoch 5/10 average loss = 5131.050011625744, purity = 0.5325
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5122.698451450893
# Loss on sub_epoch 11/30: 5072.757672991072
# Loss on sub_epoch 21/30: 5161.661969866072
# Updating lr
# On epoch 6/10 average loss = 5134.612381417411, purity = 0.5325
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5203.600306919643
# Loss on sub_epoch 11/30: 5174.356166294643
# Loss on sub_epoch 21/30: 5165.421037946428
# On epoch 7/10 average loss = 5146.335172526042, purity = 0.53
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5125.770786830357
# Updating lr
# Loss on sub_epoch 11/30: 5163.946637834822
# Loss on sub_epoch 21/30: 5156.854701450893
# Updating lr
# On epoch 8/10 average loss = 5144.761637369792, purity = 0.5237499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5193.041713169643
# Loss on sub_epoch 11/30: 5125.457310267857
# Loss on sub_epoch 21/30: 5175.392578125
# Updating lr
# On epoch 9/10 average loss = 5153.18179640997, purity = 0.52
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5121.601911272322
# Loss on sub_epoch 11/30: 5135.039620535715
# Loss on sub_epoch 21/30: 5099.699637276785
# Updating lr
# On epoch 10/10 average loss = 5147.301834542411, purity = 0.52125
# div: 128 0.71325 +- 0.07893668348746354
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.50375
# Beginning m-step
# Loss on sub_epoch 1/30: 8629.774832589286
# Loss on sub_epoch 11/30: 6173.146135602678
# Loss on sub_epoch 21/30: 5897.361188616072
# On epoch 1/10 average loss = 6297.2577822730655, purity = 0.7424999999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5418.619349888393
# Loss on sub_epoch 11/30: 5154.915666852678
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.5175
# Beginning m-step
# Loss on sub_epoch 1/30: 9002.676688058036
# Loss on sub_epoch 11/30: 6149.254185267857
# Loss on sub_epoch 21/30: 5603.755650111607
# On epoch 1/10 average loss = 6250.2703148251485, purity = 0.5062500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5343.259765625
# Loss on sub_epoch 11/30: 5243.983956473215
# Loss on sub_epoch 21/30: 5026.520577566965
# Updating lr
# On epoch 2/10 average loss = 5087.024372209821, purity = 0.5525
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4920.39208984375
# Loss on sub_epoch 11/30: 4910.007393973215
# Loss on sub_epoch 21/30: 4833.597795758928
# Updating lr
# On epoch 3/10 average loss = 4879.000841703869, purity = 0.69375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4854.104561941965
# Loss on sub_epoch 11/30: 4930.937151227678
# Loss on sub_epoch 21/30: 4846.524972098215
# Updating lr
# On epoch 4/10 average loss = 4864.683442615327, purity = 0.775
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4888.850864955357
# Loss on sub_epoch 11/30: 4861.523856026785
# Loss on sub_epoch 21/30: 4853.549525669643
# On epoch 5/10 average loss = 4870.2817894345235, purity = 0.78625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Updating lr
# Loss on sub_epoch 1/30: 4864.282924107143
# Loss on sub_epoch 11/30: 4864.77734375
# Loss on sub_epoch 21/30: 4952.076450892857
# Updating lr
# On epoch 6/10 average loss = 4867.973544456845, purity = 0.78
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4898.398228236607
# Loss on sub_epoch 11/30: 4868.373186383928
# Loss on sub_epoch 21/30: 4790.920061383928
# Updating lr
# On epoch 7/10 average loss = 4869.188423084077, purity = 0.77125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4859.310895647322
# Loss on sub_epoch 11/30: 4869.444266183035
# Loss on sub_epoch 21/30: 4887.371651785715
# On epoch 8/10 average loss = 4864.605880301339, purity = 0.7575000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4880.250418526785
# Updating lr
# Loss on sub_epoch 11/30: 4886.664829799107
# Loss on sub_epoch 21/30: 4812.336983816965
# On epoch 9/10 average loss = 4876.134256417411, purity = 0.7425
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4848.488351004465
# Updating lr
# Loss on sub_epoch 11/30: 4853.233328683035
# Loss on sub_epoch 21/30: 4866.036690848215
# On epoch 10/10 average loss = 4868.688620721726, purity = 0.73375
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.51
# Beginning m-step
# Loss on sub_epoch 1/30: 9033.69614955357
# Loss on sub_epoch 11/30: 6273.26318359375
# Loss on sub_epoch 21/30: 5784.116280691965
# On epoch 1/10 average loss = 6420.246254185268, purity = 0.8674999999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5434.354282924107
# Loss on sub_epoch 11/30: 5198.698939732143
# Loss on sub_epoch 21/30: 4970.623046875
# On epoch 2/10 average loss = 5140.531763857887, purity = 0.7375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4895.596330915178
# Updating lr
# Loss on sub_epoch 11/30: 4844.176827566965
# Loss on sub_epoch 21/30: 4851.385811941965
# On epoch 3/10 average loss = 4860.1602074032735, purity = 0.83875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4817.839146205357
# Updating lr
# Loss on sub_epoch 11/30: 4767.688197544643
# Loss on sub_epoch 21/30: 4901.689522879465
# On epoch 4/10 average loss = 4835.28482375372, purity = 0.89
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4861.042201450893
# Updating lr
# Loss on sub_epoch 11/30: 4882.902134486607
# Loss on sub_epoch 21/30: 4800.254464285715
# On epoch 5/10 average loss = 4840.011604817709, purity = 0.8925000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4809.641252790178
# Updating lr
# Loss on sub_epoch 11/30: 4826.007533482143
# Loss on sub_epoch 21/30: 4831.939592633928
# On epoch 6/10 average loss = 4848.649346633185, purity = 0.8975
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4866.451799665178
# Updating lr
# Loss on sub_epoch 11/30: 4790.225027901785
# Loss on sub_epoch 21/30: 4856.268415178572
# On epoch 7/10 average loss = 4838.2102492559525, purity = 0.8975
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4835.563825334822
# Updating lr
# Loss on sub_epoch 11/30: 4855.560198102678
# Loss on sub_epoch 21/30: 4825.409807477678
# On epoch 8/10 average loss = 4850.968629092262, purity = 0.8987499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4837.072544642857
# Updating lr
# Loss on sub_epoch 11/30: 4854.789411272322
# Loss on sub_epoch 21/30: 4827.685546875
# On epoch 9/10 average loss = 4826.6475086030505, purity = 0.8987499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4780.3125
# Updating lr
# Loss on sub_epoch 11/30: 4846.990094866072
# Loss on sub_epoch 21/30: 4787.862513950893
# On epoch 10/10 average loss = 4830.504196893601, purity = 0.8987499999999999
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.5375
# Beginning m-step
# Loss on sub_epoch 1/30: 8916.90122767857
# Loss on sub_epoch 11/30: 6247.253627232143
# Loss on sub_epoch 21/30: 6047.5595703125
# On epoch 1/10 average loss = 6406.8179152715775, purity = 0.6025
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5541.034946986607
# Loss on sub_epoch 11/30: 5351.598702566965
# Loss on sub_epoch 21/30: 5154.457170758928
# On epoch 2/10 average loss = 5230.817247953869, purity = 0.7350000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Updating lr
# Loss on sub_epoch 1/30: 5004.2822265625
# Loss on sub_epoch 11/30: 4969.701171875
# Loss on sub_epoch 21/30: 4925.282679966518
# On epoch 3/10 average loss = 4931.120639183408, purity = 0.88625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4842.634347098215
# Updating lr
# Loss on sub_epoch 11/30: 4956.91650390625
# Loss on sub_epoch 21/30: 4783.118443080357
# On epoch 4/10 average loss = 4899.83720703125, purity = 0.9275
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4964.296107700893
# Updating lr
# Loss on sub_epoch 11/30: 4908.070033482143
# Loss on sub_epoch 21/30: 4866.228724888393
# On epoch 5/10 average loss = 4900.272351655506, purity = 0.93125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4866.283482142857
# Updating lr
# Loss on sub_epoch 11/30: 4912.81298828125
# Loss on sub_epoch 21/30: 4873.740094866072
# On epoch 6/10 average loss = 4904.2628138950895, purity = 0.93625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4943.732631138393
# Updating lr
# Loss on sub_epoch 11/30: 4936.392299107143
# Loss on sub_epoch 21/30: 4926.562848772322
# On epoch 7/10 average loss = 4902.231937081473, purity = 0.93625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4805.43798828125
# Updating lr
# Loss on sub_epoch 11/30: 4908.151436941965
# Loss on sub_epoch 21/30: 4819.889369419643
# On epoch 8/10 average loss = 4887.113044084821, purity = 0.93625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4915.442592075893
# Loss on sub_epoch 11/30: 4893.567940848215
# Updating lr
# Loss on sub_epoch 21/30: 4933.970145089285
# On epoch 9/10 average loss = 4891.236704799107, purity = 0.93625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4896.75927734375
# Loss on sub_epoch 11/30: 4895.681570870535
# Updating lr
# Loss on sub_epoch 21/30: 4910.377022879465
# On epoch 10/10 average loss = 4904.650425502232, purity = 0.93625
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.50625
# Beginning m-step
# Loss on sub_epoch 1/30: 9037.635044642857
# Loss on sub_epoch 11/30: 6348.899832589285
# Loss on sub_epoch 21/30: 5838.951729910715
# On epoch 1/10 average loss = 6339.428208705357, purity = 0.6950000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5411.129255022322
# Loss on sub_epoch 11/30: 5138.893833705357
# Loss on sub_epoch 21/30: 5043.134068080357
# Updating lr
# On epoch 2/10 average loss = 5136.770917038691, purity = 0.52
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4908.370535714285
# Loss on sub_epoch 11/30: 4871.951171875
# Loss on sub_epoch 21/30: 4763.907784598215
# Updating lr
# On epoch 3/10 average loss = 4875.8179013206845, purity = 0.63625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4933.699776785715
# Loss on sub_epoch 11/30: 4947.4677734375
# Loss on sub_epoch 21/30: 4802.079310825893
# On epoch 4/10 average loss = 4855.772156343006, purity = 0.715
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Updating lr
# Loss on sub_epoch 1/30: 4811.071707589285
# Loss on sub_epoch 11/30: 4833.120256696428
# Loss on sub_epoch 21/30: 4803.925990513393
# Updating lr
# On epoch 5/10 average loss = 4847.708620489211, purity = 0.72125
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4887.525320870535
# Loss on sub_epoch 11/30: 4861.501046316965
# Loss on sub_epoch 21/30: 4830.4189453125
# Updating lr
# On epoch 6/10 average loss = 4859.411028180803, purity = 0.70875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4881.527553013393
# Loss on sub_epoch 11/30: 4868.708356584822
# Loss on sub_epoch 21/30: 4844.58544921875
# Updating lr
# On epoch 7/10 average loss = 4857.880140904018, purity = 0.69875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4862.1044921875
# Loss on sub_epoch 11/30: 4838.080705915178
# Loss on sub_epoch 21/30: 4908.415666852678
# Updating lr
# On epoch 8/10 average loss = 4863.498395647322, purity = 0.6775
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4913.756696428572
# Loss on sub_epoch 11/30: 4884.851492745535
# Loss on sub_epoch 21/30: 4843.588169642857
# Updating lr
# On epoch 9/10 average loss = 4862.243294270834, purity = 0.66
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4832.836774553572
# Loss on sub_epoch 11/30: 4860.098772321428
# Loss on sub_epoch 21/30: 4830.02800641741
# Updating lr
# On epoch 10/10 average loss = 4853.380834960937, purity = 0.6475
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.525
# Beginning m-step
# Loss on sub_epoch 1/30: 8975.962193080357
# Loss on sub_epoch 11/30: 6315.005440848215
# Loss on sub_epoch 21/30: 5621.342354910715
# On epoch 1/10 average loss = 6288.029450334821, purity = 0.6637500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 5371.574916294643
# Loss on sub_epoch 11/30: 5195.980817522322
# Loss on sub_epoch 21/30: 5056.26806640625
# Updating lr
# On epoch 2/10 average loss = 5111.010102771577, purity = 0.615
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4910.202497209822
# Loss on sub_epoch 11/30: 4916.176130022322
# Loss on sub_epoch 21/30: 4822.384695870535
# Updating lr
# On epoch 3/10 average loss = 4899.117656017485, purity = 0.5375000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4896.769112723215
# Loss on sub_epoch 11/30: 4947.499930245535
# Loss on sub_epoch 21/30: 4885.304547991072
# Updating lr
# On epoch 4/10 average loss = 4873.5414736793155, purity = 0.5425
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4863.988699776785
# Loss on sub_epoch 11/30: 4893.803431919643
# Loss on sub_epoch 21/30: 4855.558837890625
# On epoch 5/10 average loss = 4880.957527669271, purity = 0.54
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Updating lr
# Loss on sub_epoch 1/30: 4918.333286830357
# Loss on sub_epoch 11/30: 4932.970563616072
# Loss on sub_epoch 21/30: 4912.439732142857
# On epoch 6/10 average loss = 4882.778136625744, purity = 0.53625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4893.476353236607
# Updating lr
# Loss on sub_epoch 11/30: 4869.374581473215
# Loss on sub_epoch 21/30: 4891.363630022322
# Updating lr
# On epoch 7/10 average loss = 4878.02142624628, purity = 0.53625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4863.712541852678
# Loss on sub_epoch 11/30: 4899.087541852678
# Loss on sub_epoch 21/30: 4792.224888392857
# Updating lr
# On epoch 8/10 average loss = 4879.63912062872, purity = 0.53375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4868.603166852678
# Loss on sub_epoch 11/30: 4883.398228236607
# Loss on sub_epoch 21/30: 4857.027204241072
# Updating lr
# On epoch 9/10 average loss = 4872.546526227678, purity = 0.5325
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 4890.186732700893
# Loss on sub_epoch 11/30: 4903.849469866072
# Loss on sub_epoch 21/30: 4936.632533482143
# Updating lr
# On epoch 10/10 average loss = 4881.130040922619, purity = 0.53125
# div: 256 0.8012499999999999 +- 0.10321094903158289

# %%
print('div 16 0.6295 +- 0.09964813094')
# Out:
# div 16 0.6295 +- 0.09964813094

# %%
purs
# Out:
# [0.50125,
#  0.7875000000000001,
#  0.9625,
#  0.99,
#  0.9924999999999999,
#  0.9924999999999999,
#  0.9924999999999999,
#  0.9924999999999999,
#  0.9924999999999999,
#  0.9924999999999999,
#  0.784]

# %%
stds
# Out:
# [0.030335622624235017,
#  0.0650163440990033,
#  0.06638147331899162,
#  0.13284012947900947,
#  0.16613887263370963,
#  0.19262560837022688,
#  0.17143037945475123]

# %%
import numpy as np
n_tries = 0
purs = []
stds = []
divs = [16,32,64,128,256]
for div in divs:
    res = []
    while n_tries<5:
        data, target = get_dataset(path_to_files, 5, 512)
        device = 'cuda:0'

        model = LSTM_cluster_point_processes(6, div, 3, 5, 2, dropout = 0.1).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
        trainer = Trainer_clusterwise(model, optimizer, device, data, target, 2,\
                                 max_epochs = 10, max_m_step_epochs = 30,\
                                  lr_update_tol = 15, lr_update_param = 0.1,
                                  batch_size = 100)
        losses, purys = trainer.train()
        if purys:
            res.append(max(purys))
            n_tries += 1
    print('hidden_size:',div,np.mean(res),'+-', np.std(res))
    purs.append(np.mean(res))
    stds.append(np.std(res))
    n_tries = 0
# Out:
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.50625
# Beginning m-step
# Loss on sub_epoch 1/30: 25428.183035714286
# Loss on sub_epoch 11/30: 24460.67159598214
# Loss on sub_epoch 21/30: 23034.750837053572
# On epoch 1/10 average loss = 23730.872023809523, purity = 0.56625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 22385.310546875
# Loss on sub_epoch 11/30: 22205.417131696428
# Loss on sub_epoch 21/30: 22005.378069196428
# On epoch 2/10 average loss = 22218.565578497022, purity = 0.5825
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 22109.06640625
# Loss on sub_epoch 11/30: 21886.440011160714
# Updating lr
# Loss on sub_epoch 21/30: 21831.343191964286
# On epoch 3/10 average loss = 21926.311002604165, purity = 0.77
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21782.83565848214
# Loss on sub_epoch 11/30: 21838.365234375
# Loss on sub_epoch 21/30: 21804.295758928572
# Updating lr
# On epoch 4/10 average loss = 21799.083231026787, purity = 0.83875
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21750.119140625
# Loss on sub_epoch 11/30: 21777.54659598214
# Loss on sub_epoch 21/30: 21771.41768973214
# Updating lr
# On epoch 5/10 average loss = 21761.254464285714, purity = 0.86
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21732.59151785714
# Loss on sub_epoch 11/30: 21753.76981026786
# Updating lr
# Loss on sub_epoch 21/30: 21784.077566964286
# On epoch 6/10 average loss = 21757.446326264882, purity = 0.8712500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21755.883370535714
# Loss on sub_epoch 11/30: 21746.140625
# Updating lr
# Loss on sub_epoch 21/30: 21755.339006696428
# On epoch 7/10 average loss = 21754.19503348214, purity = 0.8775
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21724.24246651786
# Loss on sub_epoch 11/30: 21817.66378348214
# Loss on sub_epoch 21/30: 21741.061941964286
# Updating lr
# On epoch 8/10 average loss = 21757.798604910713, purity = 0.8812500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21735.200613839286
# Loss on sub_epoch 11/30: 21761.294363839286
# Updating lr
# Loss on sub_epoch 21/30: 21730.169084821428
# On epoch 9/10 average loss = 21755.62775297619, purity = 0.8812500000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21744.04659598214
# Loss on sub_epoch 11/30: 21750.405133928572
# Updating lr
# Loss on sub_epoch 21/30: 21778.342354910714
# On epoch 10/10 average loss = 21760.913020833334, purity = 0.8800000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.50125
# Beginning m-step
# Loss on sub_epoch 1/30: 26318.070870535714
# Loss on sub_epoch 11/30: 24620.00558035714
# Loss on sub_epoch 21/30: 23408.97265625
# On epoch 1/10 average loss = 24115.341629464285, purity = 0.5275
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 22829.974609375
# Loss on sub_epoch 11/30: 22349.657366071428
# Loss on sub_epoch 21/30: 22107.859933035714
# On epoch 2/10 average loss = 22282.82379092262, purity = 0.51625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21992.971540178572
# Loss on sub_epoch 11/30: 21855.180524553572
# Updating lr
# Loss on sub_epoch 21/30: 22197.325613839286
# On epoch 3/10 average loss = 21939.737388392856, purity = 0.69375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21763.321428571428
# Loss on sub_epoch 11/30: 21800.16964285714
# Loss on sub_epoch 21/30: 21796.05636160714
# Updating lr
# On epoch 4/10 average loss = 21794.771484375, purity = 0.88
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21718.669084821428
# Loss on sub_epoch 11/30: 21713.446428571428
# Updating lr
# Loss on sub_epoch 21/30: 21707.996651785714
# On epoch 5/10 average loss = 21721.464527529763, purity = 0.9325000000000001
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21707.26953125
# Loss on sub_epoch 11/30: 21693.104910714286
# Updating lr
# Loss on sub_epoch 21/30: 21750.40262276786
# On epoch 6/10 average loss = 21717.47646019345, purity = 0.93625
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21685.80440848214
# Loss on sub_epoch 11/30: 21720.29268973214
# Updating lr
# Loss on sub_epoch 21/30: 21759.08565848214
# On epoch 7/10 average loss = 21716.616713169642, purity = 0.9375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21704.85909598214
# Loss on sub_epoch 11/30: 21707.270926339286
# Updating lr
# Loss on sub_epoch 21/30: 21691.03125
# On epoch 8/10 average loss = 21708.782347470238, purity = 0.9375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21686.304129464286
# Loss on sub_epoch 11/30: 21724.178571428572
# Updating lr
# Loss on sub_epoch 21/30: 21730.47237723214
# On epoch 9/10 average loss = 21712.580068824405, purity = 0.9375
# Beginning e-step
# tensor(800., device='cuda:0')
# Beginning m-step
# Loss on sub_epoch 1/30: 21692.039620535714
# Loss on sub_epoch 11/30: 21694.07003348214
# Updating lr
# Loss on sub_epoch 21/30: 21714.759765625
# On epoch 10/10 average loss = 21715.003738839285, purity = 0.9375
# Beginning e-step
# tensor(800., device='cuda:0')
# Purity for random model: 0.5175000000000001
# Beginning m-step
# Loss on sub_epoch 1/30: 25612.751116071428
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-5-5994952fdb85> in <module>
#      16                                   lr_update_tol = 15, lr_update_param = 0.1,
#      17                                   batch_size = 100)
# ---> 18         losses, purys = trainer.train()
#      19         if purys:
#      20             res.append(max(purys))
#
# /mnt/Cohort-Intensity/utils/trainers.py in train(self)
#     179                 print('Purity for random model: {}'.format(random_pur))
#     180             print('Beginning m-step')
# --> 181             ll, pur =  self.m_step()
#     182             if ll == None:
#     183                 return None, None
#
# /mnt/Cohort-Intensity/utils/trainers.py in m_step(self)
#     153         log_likelihood = []
#     154         for epoch in range(self.max_m_step_epochs):
# --> 155             ll = self.train_epoch(epoch)
#     156             log_likelihood += ll
#     157             if np.mean(ll) != np.mean(ll):
#
# /mnt/Cohort-Intensity/utils/trainers.py in train_epoch(self, epoch)
#     135             batch = self.X[batch_ids].to(self.device)
#     136             self.optimizer.zero_grad()
# --> 137             lambdas = self.model(batch).to(self.device)
#     138             loss = self.loss(batch, lambdas, batch_ids)
#     139             loss.backward()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# /mnt/Cohort-Intensity/models/models.py in forward(self, s, provide_states)
#     107                 h0 = hidden0[-1, 0, :].reshape(-1)
#     108             lambdas[k,:,0,:] = getattr(self,'f_{}'.format(k))(h0 @ self.W)[None,:].repeat(bs,1)
# --> 109             lambdas[k,:,1:,:] = getattr(self,'f_{}'.format(k))(out[:,:-1,:] @ self.W)
#     110         if provide_states:
#     111             return lambdas, hidden, cell
#
# KeyboardInterrupt:

# %%
import torch
import pickle
with open('success.pkl', 'rb') as f:
    a = pickle.load(f)

# %%
a
# Out:
# []
