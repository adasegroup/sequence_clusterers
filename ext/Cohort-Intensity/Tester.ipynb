# %%
import pickle
import torch
from models.models import LSTM_cluster_point_processes
from utils.trainers import Trainer_clusterwise

with open('utils/data.pkl', 'rb') as f:
    data = pickle.load(f)
    
with open('utils/clusters.pkl', 'rb') as f:
    target = pickle.load(f)
device = 'cuda:0'

model = LSTM_cluster_point_processes(6, 32, 1, 5, 5, 128).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
trainer = Trainer_clusterwise(model, optimizer, device, data, data, target, target, 5)

# %%
losses, purs, purs_val = trainer.train()
# Out:
# Beginning e-step
# tensor(2000., device='cuda:0')
# Purity for random model: 0.628
# Beginning m-step
# Loss on sub_epoch 1/30: 356835.22450657893
# Loss on sub_epoch 11/30: 46962.64155016447
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-3-64226e875129> in <module>
# ----> 1 losses, purs, purs_val = trainer.train()
#
# /mnt/Cohort-Intensity/utils/trainers.py in train(self)
#     191                 print('Purity for random model: {}'.format(random_pur))
#     192             print('Beginning m-step')
# --> 193             ll, ll_pur =  self.m_step()
#     194             if ll == None:
#     195                 return None, None, None
#
# /mnt/Cohort-Intensity/utils/trainers.py in m_step(self)
#     164         log_likelihood_curve = []
#     165         for epoch in range(self.max_m_step_epochs):
# --> 166             ll = self.train_epoch(epoch)
#     167             log_likelihood_curve += ll
#     168             if np.mean(ll) != np.mean(ll):
#
# ...

# %%
data
# Out:
# tensor([[[ 4.0506,  0.0000,  2.0000,  3.0000, 17.0000, 24.0000],
#          [ 4.0506,  8.0000,  1.0000,  0.0000,  1.0000,  7.0000],
#          [ 4.0506, 10.0000,  0.0000,  0.0000,  1.0000,  2.0000],
#          ...,
#          [ 4.0506, 13.0000,  0.0000, 14.0000,  9.0000,  9.0000],
#          [ 4.0506, 15.0000,  0.0000, 12.0000, 14.0000, 11.0000],
#          [ 4.0506,  4.0000,  0.0000,  8.0000, 10.0000, 11.0000]],
#
#         [[ 8.9780,  0.0000,  1.0000,  6.0000, 34.0000, 80.0000],
#          [ 8.9780, 26.0000,  0.0000,  0.0000,  2.0000, 10.0000],
#          [ 8.9780,  7.0000,  6.0000,  0.0000,  1.0000,  8.0000],
#          ...,
#          [ 8.9780, 18.0000,  0.0000,  6.0000, 23.0000, 18.0000],
#          [ 8.9780, 21.0000,  1.0000, 19.0000,  8.0000, 18.0000],
#          [ 8.9780, 19.0000,  0.0000, 15.0000, 17.0000, 22.0000]],
#
#         [[ 7.9792,  1.0000,  2.0000,  5.0000, 40.0000, 54.0000],
#          [ 7.9792, 29.0000,  1.0000,  0.0000,  6.0000, 14.0000],
# ...

# %%
target.shape
# Out:
# torch.Size([2000])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data[5,:,1])

# %%
for i in range(5):
    plt.plot(data[i*400,:,1])
    plt.plot(data[i*400+10,:,1])
    plt.show()
