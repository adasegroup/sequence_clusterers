# %%
from data_generator import generate_dataset

# %%
data, target = generate_dataset(5, 5, 400, 128, 32, 1, 10, 'test')
# Out:
# Generating batch 1/400
# >>> Generating sequence step 1/128
# >>> Generating sequence step 101/128
# Generating batch 2/400
# >>> Generating sequence step 1/128
# >>> Generating sequence step 101/128
# Generating batch 3/400
# >>> Generating sequence step 1/128
# >>> Generating sequence step 101/128
# Generating batch 4/400
# >>> Generating sequence step 1/128
# >>> Generating sequence step 101/128
# Generating batch 5/400
# >>> Generating sequence step 1/128
# >>> Generating sequence step 101/128
# Generating batch 6/400
# >>> Generating sequence step 1/128
# >>> Generating sequence step 101/128
# Generating batch 7/400
# >>> Generating sequence step 1/128
# >>> Generating sequence step 101/128
# Generating batch 8/400
# >>> Generating sequence step 1/128
# >>> Generating sequence step 101/128
# Generating batch 9/400
# >>> Generating sequence step 1/128
# >>> Generating sequence step 101/128
# Generating batch 10/400
# >>> Generating sequence step 1/128
# ...

# %%
data.shape
# Out:
# torch.Size([2000, 128, 6])

# %%
target
# Out:
# tensor([0., 0., 0.,  ..., 4., 4., 4.])

# %%
import pickle

# %%
with open('data.pkl', 'wb') as f:
    pickle.dump(data, f)
with open('clusters.pkl', 'wb') as f:
    pickle.dump(target, f)

# %%
import torch

# %%
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
data.max()
# Out:
# tensor(115.)
